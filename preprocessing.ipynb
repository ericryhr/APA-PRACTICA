# %% [markdown]
# # Data description and preprocessing

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Loading the data

# %%
numeric_variables = []
with open('dataset.txt', 'r') as file:
    for line in file:
        line = line.strip()
        line = line.replace('\'', '').replace('\\', '\'').replace('\'"', '"')

        data = line.split(',', 1)[1]
        n = data.count(',')
        data = data.replace(',', '', n - 13)
        data = data.split(',')
        numeric_variables.append(data)

df = pd.DataFrame(numeric_variables, columns=['Title', 'Artist', 'Genre', 'Year', 'BPM', 'Energy', 'Danceability', 'Loudness', 'Liveness', 'Valence', 'Length', 'Acousticness', 'Speechiness', 'Popularity'])
df.head()
# Out:
#                     Title             Artist                Genre  Year  BPM  \
# 0                 Sunrise        Norah Jones      adult standards  2004  157
# 1             Black Night        Deep Purple           album rock  2000  135
# 2          Clint Eastwood           Gorillaz  alternative hip hop  2001  168
# 3           The Pretender       Foo Fighters    alternative metal  2007  173
# 4  Waitin' On A Sunny Day  Bruce Springsteen         classic rock  2002  106
#
#   Energy Danceability Loudness Liveness Valence Length Acousticness  \
# 0     30           53      -14       11      68    201           94
# 1     79           50      -11       17      81    207           17
# 2     69           66       -9        7      52    341            2
# 3     96           43       -4        3      37    269            0
# 4     82           58       -5       10      87    256            1
#
#   Speechiness Popularity
# 0           3         71
# 1           7         39
# 2          17         69
# 3           4         76
# 4           3         59

# %%
X = df.drop(columns='Year')
Y = df['Year']

# %%
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

# %%
# df_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.7, random_state=0)

# %% [markdown]
# ### Analysis

# %%
df_train.isnull().sum()
# Out:
# Title           0
# Artist          0
# Genre           0
# Year            0
# BPM             0
# Energy          0
# Danceability    0
# Loudness        0
# Liveness        0
# Valence         0
# Length          0
# Acousticness    0
# Speechiness     0
# Popularity      0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1395 entries, 482 to 684
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         1395 non-null   object
#  1   Artist        1395 non-null   object
#  2   Genre         1395 non-null   object
#  3   Year          1395 non-null   object
#  4   BPM           1395 non-null   object
#  5   Energy        1395 non-null   object
#  6   Danceability  1395 non-null   object
#  7   Loudness      1395 non-null   object
#  8   Liveness      1395 non-null   object
#  9   Valence       1395 non-null   object
#  10  Length        1395 non-null   object
#  11  Acousticness  1395 non-null   object
#  12  Speechiness   1395 non-null   object
#  13  Popularity    1395 non-null   object
# dtypes: object(14)
# memory usage: 163.5+ KB

# %% [markdown]
# Converting columns to string / int

# %%
for header in df_train.columns[3:10]:
    df_train[header] = df_train[header].astype(int)
for header in df_train.columns[11:]:
    df_train[header] = df_train[header].astype(int)

# %%
df_train[df_train["Length"].str.contains("\.")==True]
# Out:
#                                                   Title      Artist  \
# 842                                              Echoes  Pink Floyd
# 904   Close to the Edge (i. The Solid Time of Change...         Yes
# 1982                                          Get Ready  Rare Earth
# 951                            Autobahn - 2009 Remaster   Kraftwerk
#
#            Genre  Year  BPM  Energy  Danceability  Loudness  Liveness  \
# 842   album rock  1971  134      32            28       -17        11
# 904   album rock  1972   81      60            22       -11        41
# 1982  blues rock  1969  127      87            41        -6        83
# 951   dance rock  1974   82      50            33       -16        13
#
#       Valence Length  Acousticness  Speechiness  Popularity
# 842        14  1.412            37            4          58
# 904        25  1.121            27            6          47
# 1982       65  1.292             0            4          45
# 951        11  1.367            11            4          48

# %% [markdown]
# Manually corrected

# %%
df_train["Length"] = df_train["Length"].replace(["1.412","1.121","1.367","1.292"], ['1412','1121','1367','1292'])
df_train["Length"] = df_train["Length"].astype(int)

# %%
df_train.describe().T
# Out:
#                count         mean        std     min     25%     50%     75%  \
# Year          1395.0  1992.931183  16.064866  1958.0  1979.0  1993.0  2007.0
# BPM           1395.0   121.298208  27.917509    37.0   100.0   120.0   136.0
# Energy        1395.0    59.939785  21.966208     5.0    43.0    62.0    78.0
# Danceability  1395.0    53.384946  15.146825    10.0    43.0    54.0    64.0
# Loudness      1395.0    -8.989964   3.617852   -27.0   -11.0    -8.0    -6.0
# Liveness      1395.0    19.264516  17.079135     2.0     9.0    12.0    23.5
# Valence       1395.0    49.970609  24.722445     3.0    29.0    48.0    70.0
# Length        1395.0   264.085305  99.586602   102.0   212.0   246.0   290.0
# Acousticness  1395.0    28.690323  28.617627     0.0     4.0    18.0    49.0
# Speechiness   1395.0     5.013620   4.468826     2.0     3.0     4.0     5.0
# Popularity    1395.0    59.751971  14.346356    11.0    50.0    62.0    71.0
#
#                  max
# Year          2019.0
# BPM            205.0
# Energy         100.0
# Danceability    96.0
# Loudness        -2.0
# Liveness        98.0
# Valence         99.0
# Length        1412.0
# Acousticness    98.0
# Speechiness     55.0
# Popularity      98.0

# %% [markdown]
# ## Data description

# %%
sns.set()
df_train.hist(bins=20, figsize=(20,15));

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# #### Title
# We have 1959 unique values out of 1994. By intuition, this feature will not provide any intuition about the year of release.
#
# <span style="color:orange">POTSER PROVAR DE SELECCIONAR PARAULA SIGNIFICATIVA, PERO MASSA LIÓS. PROVAR NOMÉS SI ELS MODELS VAN MOLT MALAMENT</span>

# %%
df_train['Title'].nunique(), len(df_train)
# Out:
# (1372, 1395)

# %%
df_train = df_train.drop(labels=['Title'], axis=1)

# %% [markdown]
# Check if we have any duplicated song

# %%
df_train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Artist

# %%
df_train['Artist'].nunique()
# Out:
# 608

# %%
artists_freq = df_train['Artist'].value_counts().reset_index()
top_artists = artists_freq.head(15)['Artist']

df_train_topArtists = df_train[df_train['Artist'].isin(top_artists)]
artist_year_range = df_train_topArtists.groupby('Artist')['Year'].agg(['min', 'max']).reset_index()

fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(artist_year_range['Artist'], height=artist_year_range['max'] - artist_year_range['min'], bottom=artist_year_range['min'])

ax.set_xlabel('Artist')
ax.set_ylabel('Year Range')
ax.set_title('Year Range for Top Artists')
ax.set_xticklabels(artist_year_range['Artist'], rotation=90)
plt.show()

# %% [markdown]
# Artist can help us narrow down the possible year for a song.

# %% [markdown]
# #### Genre

# %%
df_train['Genre'].nunique()
# Out:
# 133

# %%
top_genres = df_train['Genre'].value_counts().head(20).index
df_train_topGenres = df_train[df_train['Genre'].isin(top_genres)]

fig, ax = plt.subplots()
for genre, group in df_train_topGenres.groupby('Genre'):
    ax.scatter([genre] * len(group), group['Year'], label=genre, alpha=0.7)

ax.set_xlabel('Genre')
ax.set_ylabel('Year')
ax.set_title('Year Range for Top Genres')
plt.xticks(rotation=90)
plt.show()

# %%
df_train['Genre'].value_counts().unique()
# Out:
# array([303,  83,  59,  57,  55,  45,  43,  38,  36,  34,  30,  26,  22,
#         21,  18,  16,  15,  14,  13,  12,  11,   9,   8,   7,   6,   5,
#          4,   3,   2,   1])

# %%
fig, ax = plt.subplots()
top_genres = df_train['Genre'].value_counts()
top_genres = top_genres[top_genres > 15]
ax.bar(top_genres.index, top_genres)

ax.set_xlabel('Genre')
ax.set_ylabel('Frequency')
ax.set_title('Frequency for Genre')
plt.xticks(rotation=90)
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans

# %%
vectorizer = CountVectorizer()
df_train_vectorizer = vectorizer.fit_transform(df_train['Genre']).toarray()

inertia_values = []

for k in range(1, 30):
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(df_train_vectorizer)
    inertia_values.append(kmeans.inertia_);

plt.plot(range(1, 30), inertia_values, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.show()

# %%
# Apply K-Means clustering with the desired number of clusters
kmeans = KMeans(n_clusters=8, random_state=0);
df_train['GenreCluster'] = kmeans.fit_predict(df_train_vectorizer);
for cluster_id in range(df_train['GenreCluster'].nunique()):
    cluster_genres = df_train[df_train['GenreCluster'] == cluster_id]['Genre'].unique()
    print(f"Cluster {cluster_id}: {', '.join(cluster_genres)}")
# Out:
# Cluster 0: dutch indie, dutch hip hop, dutch cabaret, dutch prog, dutch americana, dutch metal
# Cluster 1: modern rock, alternative rock, irish rock, glam rock, art rock, danish pop rock, dance rock, classic rock, australian alternative rock, garage rock, alternative pop rock, belgian rock, blues rock, australian rock, dutch rock, celtic rock, modern folk rock, soft rock, canadian rock, german pop rock, classic canadian rock, rock-and-roll
# Cluster 2: british soul, british invasion, british singer-songwriter, british folk
# Cluster 3: album rock
# Cluster 4: adult standards
# Cluster 5: classic schlager, classic soul, classic uk pop, classic soundtrack, classic country pop, classic italian pop
# Cluster 6: permanent wave, contemporary vocal jazz, alternative metal, europop, chanson, punk, big room, blues, metropopolis, boy band, big beat, canadian folk, neo mellow, detroit hip hop, mellow gold, compositional ambient, gabba, folk, afropop, britpop, g funk, latin jazz, disco, neo soul, carnaval limburg, reggae, alternative dance, funk, scottish singer-songwriter, eurodance, glam metal, celtic, downtempo, edm, motown, arkansas country, electro, basshall, levenslied, christelijk, irish singer-songwriter, reggae fusion, bebop, alternative country, electronica, celtic punk, streektaal, latin alternative, nederpop, east coast hip hop, electropop, diva house, australian psych, cyberpunk, alaska indie, latin, austropop, ccm, finnish metal, trance, laboratorio, gangster rap, australian dance, contemporary country, electro house, chicago soul
# Cluster 7: canadian pop, dance pop, dutch pop, art pop, brill building pop, german pop, pop punk, pop, chamber pop, bow pop, folk-pop, alternative pop, bubblegum pop, australian pop, danish pop, irish pop, la pop, acoustic pop, belgian pop, hip pop, barbadian pop, baroque pop, new wave pop, operatic pop, italian pop, candy pop, indie pop

# %%
# kmeans = KMeans(n_clusters=9, random_state=0)
# df_train['GenreCluster'] = kmeans.fit_predict(X)
# for cluster_id in range(df_train['GenreCluster'].nunique()):
#     cluster_genres = df_train[df_train['GenreCluster'] == cluster_id]['Genre'].unique()
#     print(f"Cluster {cluster_id}: {', '.join(cluster_genres)}")

# %%
df_train
# Out:
#                Artist             Genre  Year  BPM  Energy  Danceability  \
# 482   Imagine Dragons       modern rock  2012  136      78            45
# 842        Pink Floyd        album rock  1971  134      32            28
# 372     Kaiser Chiefs  alternative rock  2007   93      93            44
# 576          Coldplay    permanent wave  2014   93      48            74
# 211           Tavares   adult standards  2004  117      75            61
# ...               ...               ...   ...  ...     ...           ...
# 835   Curtis Mayfield      chicago soul  1970  139      97            54
# 1216   Het Goede Doel         dutch pop  1982  141      66            58
# 1653          Nirvana  alternative rock  1994  115      39            62
# 559      Robin Thicke         dance pop  2013  120      60            85
# 684   Michael Jackson               pop  2017  118      89            76
#
#       Loudness  Liveness  Valence  Length  Acousticness  Speechiness  \
# 482         -4        67       24     187            11            6
# 842        -17        11       14    1412            37            4
# 372         -3         8       40     203             1            5
# 576         -9        11       36     285             3            4
# 211         -9        39       97     394             1            3
# ...        ...       ...      ...     ...           ...          ...
# 835         -6        12       93     166            42            9
# 1216       -14         7       66     361             1            4
# 1653       -12        91       44     196            68            4
# 559         -5         8       84     264             0            4
# 684         -4        85       72     358             8            7
#
#       Popularity  GenreCluster
# 482           73             1
# 842           58             3
# 372           62             1
# 576           73             6
# 211           49             4
# ...          ...           ...
# 835           67             6
# 1216          52             7
# 1653          57             1
# 559           76             7
# 684           69             7
#
# [1395 rows x 14 columns]

# %%
df_train = df_train.drop(columns='Genre')
df_train['GenreCluster'] = df_train['GenreCluster'].astype(str)
df_train.head()
# Out:
#               Artist  Year  BPM  Energy  Danceability  Loudness  Liveness  \
# 482  Imagine Dragons  2012  136      78            45        -4        67
# 842       Pink Floyd  1971  134      32            28       -17        11
# 372    Kaiser Chiefs  2007   93      93            44        -3         8
# 576         Coldplay  2014   93      48            74        -9        11
# 211          Tavares  2004  117      75            61        -9        39
#
#      Valence  Length  Acousticness  Speechiness  Popularity GenreCluster
# 482       24     187            11            6          73            1
# 842       14    1412            37            4          58            3
# 372       40     203             1            5          62            1
# 576       36     285             3            4          73            6
# 211       97     394             1            3          49            4

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1395 entries, 482 to 684
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Artist        1395 non-null   object
#  1   Year          1395 non-null   int64
#  2   BPM           1395 non-null   int64
#  3   Energy        1395 non-null   int64
#  4   Danceability  1395 non-null   int64
#  5   Loudness      1395 non-null   int64
#  6   Liveness      1395 non-null   int64
#  7   Valence       1395 non-null   int64
#  8   Length        1395 non-null   int64
#  9   Acousticness  1395 non-null   int64
#  10  Speechiness   1395 non-null   int64
#  11  Popularity    1395 non-null   int64
#  12  GenreCluster  1395 non-null   object
# dtypes: int64(11), object(2)
# memory usage: 152.6+ KB

# %% [markdown]
# ### BPM

# %% [markdown]
# PER LA RESTA DE VARIABLES, PROEJCTAR VARIABLE AMB TARGET i treure conclusions

# %% [markdown]
# ### One hot encoding

# %%
dummies = pd.get_dummies(df_train['Artist'], prefix='artist')
df_train = pd.concat([df_train, dummies], axis=1)
df_train = df_train.drop('Artist', axis=1)

# %%
dummies = pd.get_dummies(df_train['GenreCluster'], prefix='genre')
df_train = pd.concat([df_train, dummies], axis=1)
df_train = df_train.drop('GenreCluster', axis=1)

# %%
df_train
# Out:
#       Year  BPM  Energy  Danceability  Loudness  Liveness  Valence  Length  \
# 482   2012  136      78            45        -4        67       24     187
# 842   1971  134      32            28       -17        11       14    1412
# 372   2007   93      93            44        -3         8       40     203
# 576   2014   93      48            74        -9        11       36     285
# 211   2004  117      75            61        -9        39       97     394
# ...    ...  ...     ...           ...       ...       ...      ...     ...
# 835   1970  139      97            54        -6        12       93     166
# 1216  1982  141      66            58       -14         7       66     361
# 1653  1994  115      39            62       -12        91       44     196
# 559   2013  120      60            85        -5         8       84     264
# 684   2017  118      89            76        -4        85       72     358
#
#       Acousticness  Speechiness  ...  artist_a-ha  artist_blink-182  genre_0  \
# 482             11            6  ...        False             False    False
# 842             37            4  ...        False             False    False
# 372              1            5  ...        False             False    False
# 576              3            4  ...        False             False    False
# 211              1            3  ...        False             False    False
# ...            ...          ...  ...          ...               ...      ...
# 835             42            9  ...        False             False    False
# 1216             1            4  ...        False             False    False
# 1653            68            4  ...        False             False    False
# 559              0            4  ...        False             False    False
# 684              8            7  ...        False             False    False
#
#       genre_1  genre_2  genre_3  genre_4  genre_5  genre_6  genre_7
# 482      True    False    False    False    False    False    False
# 842     False    False     True    False    False    False    False
# 372      True    False    False    False    False    False    False
# 576     False    False    False    False    False     True    False
# 211     False    False    False     True    False    False    False
# ...       ...      ...      ...      ...      ...      ...      ...
# 835     False    False    False    False    False     True    False
# 1216    False    False    False    False    False    False     True
# 1653     True    False    False    False    False    False    False
# 559     False    False    False    False    False    False     True
# 684     False    False    False    False    False    False     True
#
# [1395 rows x 627 columns]

# %%
df_train.to_csv('df_train.csv', index=False)

# %% [markdown]
# ## Test dataset preprocessing

# %%
for header in df_test.columns[3:10]:
    df_test[header] = df_test[header].astype(int)
for header in df_test.columns[11:]:
    df_test[header] = df_test[header].astype(int)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 599 entries, 1805 to 1847
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         599 non-null    object
#  1   Artist        599 non-null    object
#  2   Genre         599 non-null    object
#  3   Year          599 non-null    int64
#  4   BPM           599 non-null    int64
#  5   Energy        599 non-null    int64
#  6   Danceability  599 non-null    int64
#  7   Loudness      599 non-null    int64
#  8   Liveness      599 non-null    int64
#  9   Valence       599 non-null    int64
#  10  Length        599 non-null    object
#  11  Acousticness  599 non-null    int64
#  12  Speechiness   599 non-null    int64
#  13  Popularity    599 non-null    int64
# dtypes: int64(10), object(4)
# memory usage: 70.2+ KB

# %%
df_test[df_test["Length"].str.contains("\.")==True]
# Out:
# Empty DataFrame
# Columns: [Title, Artist, Genre, Year, BPM, Energy, Danceability, Loudness, Liveness, Valence, Length, Acousticness, Speechiness, Popularity]
# Index: []

# %%
df_test = df_test.drop(labels=['Title'], axis=1)

# %%
df_test.duplicated().sum()
# Out:
# 0

# %%
df_test_vectorizer = vectorizer.transform(df_test['Genre']).toarray()
df_test['GenreCluster'] = kmeans.predict(df_test_vectorizer);
# for cluster_id in range(df_test['GenreCluster'].nunique()):
#     cluster_genres = df_test[df_test['GenreCluster'] == cluster_id]['Genre'].unique()
#     print(f"Cluster {cluster_id}: {', '.join(cluster_genres)}")

# %%
df_test
# Out:
#                      Artist                Genre  Year  BPM  Energy  \
# 1805  Red Hot Chili Peppers     alternative rock  1999  123      80
# 1311                  Falco            austropop  1985  106      66
# 960           Barry Manilow      adult standards  1974  104      46
# 107                  Armand           dutch rock  2009  101      69
# 1557                  Queen            glam rock  1991  116      83
# ...                     ...                  ...   ...  ...     ...
# 1431    Frank Boeijen Groep        dutch cabaret  1987  125      47
# 2                  Gorillaz  alternative hip hop  2001  168      69
# 1526                  Queen            glam rock  1991   83      69
# 1696              Faithless             big beat  1996  127      58
# 1847     The Rolling Stones           album rock  1964   99      69
#
#       Danceability  Loudness  Liveness  Valence Length  Acousticness  \
# 1805            46        -3         8       51    255             0
# 1311            65       -10        19       45    356            45
# 960             31        -9        14       32    213            42
# 107             62        -7         6       56    208            28
# 1557            64        -6        19       31    263            57
# ...            ...       ...       ...      ...    ...           ...
# 1431            60       -14        11       53    318            70
# 2               66        -9         7       52    341             2
# 1526            31        -7        11       18    278            41
# 1696            79       -10        17       26    527            18
# 1847            60       -11        33       76    206             2
#
#       Speechiness  Popularity  GenreCluster
# 1805            6          78             1
# 1311            5          58             6
# 960             3          69             4
# 107             3          47             1
# 1557            5          48             1
# ...           ...         ...           ...
# 1431            3          37             0
# 2              17          69             6
# 1526            3          58             1
# 1696            4          55             6
# 1847            3          46             3
#
# [599 rows x 14 columns]

# %%
df_test = df_test.drop(columns='Genre')
df_test['GenreCluster'] = df_test['GenreCluster'].astype(str)
df_test.head()
# Out:
#                      Artist  Year  BPM  Energy  Danceability  Loudness  \
# 1805  Red Hot Chili Peppers  1999  123      80            46        -3
# 1311                  Falco  1985  106      66            65       -10
# 960           Barry Manilow  1974  104      46            31        -9
# 107                  Armand  2009  101      69            62        -7
# 1557                  Queen  1991  116      83            64        -6
#
#       Liveness  Valence Length  Acousticness  Speechiness  Popularity  \
# 1805         8       51    255             0            6          78
# 1311        19       45    356            45            5          58
# 960         14       32    213            42            3          69
# 107          6       56    208            28            3          47
# 1557        19       31    263            57            5          48
#
#      GenreCluster
# 1805            1
# 1311            6
# 960             4
# 107             1
# 1557            1

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 599 entries, 1805 to 1847
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Artist        599 non-null    object
#  1   Year          599 non-null    int64
#  2   BPM           599 non-null    int64
#  3   Energy        599 non-null    int64
#  4   Danceability  599 non-null    int64
#  5   Loudness      599 non-null    int64
#  6   Liveness      599 non-null    int64
#  7   Valence       599 non-null    int64
#  8   Length        599 non-null    object
#  9   Acousticness  599 non-null    int64
#  10  Speechiness   599 non-null    int64
#  11  Popularity    599 non-null    int64
#  12  GenreCluster  599 non-null    object
# dtypes: int64(10), object(3)
# memory usage: 65.5+ KB

# %%
dummies = pd.get_dummies(df_train['Artist'], prefix='artist')
df_train = pd.concat([df_train, dummies], axis=1)
df_train = df_train.drop('Artist', axis=1)

# %%
dummies = pd.get_dummies(df_train['GenreCluster'], prefix='genre')
df_train = pd.concat([df_train, dummies], axis=1)
df_train = df_train.drop('GenreCluster', axis=1)

# %%
df_test

# %%
df_test.to_csv('df_test.csv', index=False)
